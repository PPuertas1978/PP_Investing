# %% [markdown]
# ## LIBRERIAS

# %%
from lxml.etree import fromstring
import pandas as pd
import calendar, requests
import os

# %% [markdown]
# ## OBTENCION DE CODES

# %%
from bs4 import BeautifulSoup

def extrae_parametros(url):
    data = requests.get(url,headers=headers)
    soup = BeautifulSoup(data.content,'html.parser')

    for a in soup.findAll("script"):
        if "smlId" in a.text:
            #print(a.text)

            texto = a.text
            texto = texto.replace(",", " ")
            i = texto.find("pairId:")+7
            aux = texto[i:].split(" ")
            aux = [x for x in aux if x!=""]
            pairId = int(aux[0])

            i = texto.find("smlId:")+6
            aux = texto[i:].split(" ")
            aux = [x for x in aux if x!=""]
            smlId = int(aux[0])
    header = soup.find(class_="instrumentHeader").find("h2").text
    return pairId, smlId, header

# %%
#url = "http://www.investing.com/commodities/gold-historical-data"
#url = "https://www.investing.com/indices/us-spx-500-historical-data"
#url = "https://www.investing.com/currencies/eur-usd-historical-data"
#url = "https://www.investing.com/currencies/gbp-usd-historical-data"
url = "https://www.investing.com/currencies/usd-inr-historical-data"

# %%
pairId, smlId, header = extrae_parametros(url)

print("pairId:", pairId)
print("smlId :", smlId)
print("Header:", header)
# Out:
# pairId: 160
# smlId : 106815
# Header: USD/INR Historical Data

# %% [markdown]
# ## CURRENCIES

# %%
#CURRIENCIES

#https://www.investing.com/currencies/eur-usd
EURUSD = {
    'name' : 'EURUSD',
    'curr_id': 1,
    'smlID': 106682,
    'header' : 'EUR/USD Historical Data',
    'sort_col' : 'date',
    'action' : 'historical_data'
}

#https://www.investing.com/currencies/usd-jpy
USDJPY = {
    'name' : 'USDJPY',
    'curr_id': 3,
    'smlID': 106684,
    'header' : 'USD/JPY Historical Data',
    'sort_col' : 'date',
    'action' : 'historical_data'
}

#https://www.investing.com/currencies/GBP-USD
GBPUSD = {
    'name' : 'GBPUSD',
    'curr_id': 2,
    'smlID': 106683,
    'header' : 'USD/JPY Historical Data',
    'sort_col' : 'date',
    'action' : 'historical_data'
}

#https://www.investing.com/currencies/USD-CHF
USDCHF = {
    'name' : 'USDCHF',
    'curr_id': 4,
    'smlID': 106685,
    'header' : 'USD/CHF Historical Data',
    'sort_col' : 'date',
    'action' : 'historical_data'
}

#https://www.investing.com/currencies/USD-CAD
USDCAD = {
    'name' : 'USDCAD',
    'curr_id': 7,
    'smlID': 106688,
    'header' : 'USD/CAD Historical Data',
    'sort_col' : 'date',
    'action' : 'historical_data'
}

#https://www.investing.com/currencies/EUR-JPY
EURJPY = {
    'name' : 'EURJPY',
    'curr_id': 9,
    'smlID': 106690,
    'header' : 'EUR/JPY Historical Data',
    'sort_col' : 'date',
    'action' : 'historical_data'
}

#https://www.investing.com/currencies/AUD-USD
AUDUSD = {
    'name' : 'AUDUSD',
    'curr_id': 5,
    'smlID': 106686,
    'header' : 'AUD/USD Historical Data',
    'sort_col' : 'date',
    'action' : 'historical_data'
}


#https://www.investing.com/currencies/NZD-USD
NZDUSD = {
    'name' : 'NZDUSD',
    'curr_id': 8,
    'smlID': 106689,
    'header' : 'AUD/USD Historical Data',
    'sort_col' : 'date',
    'action' : 'historical_data'
}


#https://www.investing.com/currencies/EUR-GBP
EURGBP = {
    'name' : 'EURGBP',
    'curr_id': 6,
    'smlID': 106687,
    'header' : 'EUR/GBP Historical Data',
    'sort_col' : 'date',
    'action' : 'historical_data'
}


#https://www.investing.com/currencies/EUR-CHF
EURCHF = {
    'name' : 'EURCHF',
    'curr_id': 10,
    'smlID': 106691,
    'header' : 'EUR/CHF Historical Data',
    'sort_col' : 'date',
    'action' : 'historical_data'
}


#https://www.investing.com/currencies/AUD-JPY
AUDJPY = {
    'name' : 'AUDJPY',
    'curr_id': 49,
    'smlID': 106710,
    'header' : 'AUD/JPY Historical Data',
    'sort_col' : 'date',
    'action' : 'historical_data'
}


#https://www.investing.com/currencies/GBP-JPY
GBPJPY = {
    'name' : 'GBPJPY',
    'curr_id': 11,
    'smlID': 106692,
    'header' : 'GBP/JPY Historical Data',
    'sort_col' : 'date',
    'action' : 'historical_data'
}


#https://www.investing.com/currencies/CHF-JPY
CHFJPY = {
    'name' : 'CHFJPY',
    'curr_id': 13,
    'smlID': 106694,
    'header' : 'CHF/JPY Historical Data',
    'sort_col' : 'date',
    'action' : 'historical_data'
}


#https://www.investing.com/currencies/EUR-CAD
EURCAD = {
    'name' : 'EURCAD',
    'curr_id': 16,
    'smlID': 106697,
    'header' : 'EUR/CAD Historical Data',
    'sort_col' : 'date',
    'action' : 'historical_data'
}


#https://www.investing.com/currencies/AUD-CAD
AUDCAD = {
    'name' : 'AUDCAD',
    'curr_id': 47,
    'smlID': 106708,
    'header' : 'AUD/CAD Historical Data',
    'sort_col' : 'date',
    'action' : 'historical_data'
}


#https://www.investing.com/currencies/CAD-JPY
CADJPY = {
    'name' : 'CADJPY',
    'curr_id': 51,
    'smlID': 106712,
    'header' : 'CAD/JPY Historical Data',
    'sort_col' : 'date',
    'action' : 'historical_data'
}


#https://www.investing.com/currencies/NZD-JPY
NZDJPY = {
    'name' : 'NZDJPY',
    'curr_id': 58,
    'smlID': 106719,
    'header' : 'NZD/JPY Historical Data',
    'sort_col' : 'date',
    'action' : 'historical_data'
}


#https://www.investing.com/currencies/AUD-NZD
AUDNZD = {
    'name' : 'AUDNZD',
    'curr_id': 50,
    'smlID': 106711,
    'header' : 'AUD/NZD Historical Data',
    'sort_col' : 'date',
    'action' : 'historical_data'
}


#https://www.investing.com/currencies/GBP-AUD
GBPAUD = {
    'name' : 'GBPAUD',
    'curr_id': 53,
    'smlID': 106714,
    'header' : 'GBP/AUD Historical Data',
    'sort_col' : 'date',
    'action' : 'historical_data'
}


#https://www.investing.com/currencies/EUR-AUD
EURAUD = {
    'name' : 'EURAUD',
    'curr_id': 15,
    'smlID': 106696,
    'header' : 'EUR/AUD Historical Data',
    'sort_col' : 'date',
    'action' : 'historical_data'
}


#https://www.investing.com/currencies/GBP-CHF
GBPCHF = {
    'name' : 'GBPCHF',
    'curr_id': 12,
    'smlID': 106693,
    'header' : 'BGP/CHF Historical Data',
    'sort_col' : 'date',
    'action' : 'historical_data'
}


#https://www.investing.com/currencies/EUR-NZD
EURNZD = {
    'name' : 'EURNZD',
    'curr_id': 52,
    'smlID': 106713,
    'header' : 'EUR/NZD Historical Data',
    'sort_col' : 'date',
    'action' : 'historical_data'
}


#https://www.investing.com/currencies/AUD-CHF
AUDCHF = {
    'name' : 'AUDCHF',
    'curr_id': 48,
    'smlID': 106709,
    'header' : 'AUD/CHF Historical Data',
    'sort_col' : 'date',
    'action' : 'historical_data'
}


#https://www.investing.com/currencies/GBP-NZD
GBPNZD = {
    'name' : 'GBPNZD',
    'curr_id': 55,
    'smlID': 106716,
    'header' : 'GBP/NZD Historical Data',
    'sort_col' : 'date',
    'action' : 'historical_data'
}


#https://www.investing.com/currencies/USD-INR
USDINR = {
    'name' : 'USDINR',
    'curr_id': 160,
    'smlID': 106815,
    'header' : 'USD/INR Historical Data',
    'sort_col' : 'date',
    'action' : 'historical_data'
}

# %%
lista_currencies = [EURUSD, USDJPY, GBPUSD, USDCHF, USDCAD, EURJPY, AUDUSD, NZDUSD, EURGBP, EURCHF, AUDJPY,
                    GBPJPY, CHFJPY, EURCAD, AUDCAD, CADJPY, NZDJPY, AUDNZD, GBPAUD, EURAUD, GBPCHF, EURNZD,
                    AUDCHF, GBPNZD, USDINR]

# %% [markdown]
# ## PARAMETROS SCRAPING

# %%
# set https header parameters
headers = {
    'User-Agent': 'Mozilla/5.0', #required 
    'referer': "https://www.investing.com",
    'host' : 'www.investing.com',
    'X-Requested-With' : 'XMLHttpRequest'
}

class IndiceHistoricalData():
    
    def __init__(self, API_url):
        self.API_url = API_url

    #set https header for request
    def setHeaders(self, headers):
        self.headers = headers 
    
    #set indice data (indices.py) 
    def setFormData(self, data):
        self.data = data 

    #prices frequency, possible values: Monthly, Weekly, Daily
    def updateFrequency(self, frequency):
        self.data['frequency'] = frequency

    #desired time period from/to
    def updateStartingEndingDate(self, startingDate, endingDate):
        self.data['st_date'] = startingDate 
        self.data['end_date'] = endingDate

    #possible values: 'DESC', 'ASC'
    def setSortOreder(self, sorting_order):
        self.data['sort_ord'] = sorting_order

    #making the post request
    def downloadData(self):
        self.response = requests.post(self.API_url, data=self.data, headers=self.headers).content
        #parse tables with pandas - [0] probably there is only one html table in response
        self.observations = pd.read_html(self.response)[0]
        return self.observations

    #print retrieved data
    def printData(self):
        print(self.observations)

    #print retrieved data
    def saveDataCSV(self, folder=None):
        if folder is None:
            self.observations.to_csv(self.data['name']+'.csv',
                                     sep='\t', encoding='utf-8')
        else:
            try:
                os.mkdir(folder)
            except:
                pass
            nombre = os.path.join(folder,self.data['name']+'.csv')
            self.observations.to_csv(nombre, sep='\t', encoding='utf-8')

# %% [markdown]
# ## SCRAPING

# %%
for currencies in lista_currencies:
    print("Realizando scraping de currencies", currencies["name"], "...")
    ihd = IndiceHistoricalData('https://www.investing.com/instruments/HistoricalDataAjax')
    ihd.setHeaders(headers)
    ihd.setFormData(currencies)

    #second set Variables
    ihd.updateFrequency('Monthly')
    ihd.updateStartingEndingDate('1/1/2019', '5/31/2019')
    ihd.setSortOreder('ASC')
    ihd.downloadData()
#    ihd.printData()
    ihd.saveDataCSV(folder="scraping_currencies")

print("\nFin de scraping currencies")
# Out:
# Realizando scraping de currencies EURUSD ...
# Realizando scraping de currencies USDJPY ...
# Realizando scraping de currencies GBPUSD ...
# Realizando scraping de currencies USDCHF ...
# Realizando scraping de currencies USDCAD ...
# Realizando scraping de currencies EURJPY ...
# Realizando scraping de currencies AUDUSD ...
# Realizando scraping de currencies NZDUSD ...
# Realizando scraping de currencies EURGBP ...
# Realizando scraping de currencies EURCHF ...
# Realizando scraping de currencies AUDJPY ...
# Realizando scraping de currencies GBPJPY ...
# Realizando scraping de currencies CHFJPY ...
# Realizando scraping de currencies EURCAD ...
# Realizando scraping de currencies AUDCAD ...
# Realizando scraping de currencies CADJPY ...
# Realizando scraping de currencies NZDJPY ...
# Realizando scraping de currencies AUDNZD ...
# Realizando scraping de currencies GBPAUD ...
# Realizando scraping de currencies EURAUD ...
# Realizando scraping de currencies GBPCHF ...
# ...
